# %%
# test this out with new Ghidra code...
import astlib
from pathlib import Path


# astlib.json_to_ast()

# %%
json_file = list((Path.home()/'test_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug').iterdir())[0]

ast, _ = astlib.json_to_ast(json_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 json_file = list((Path.home()/'test_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug').iterdir())[0]
# ----> 3 ast, _ = astlib.json_to_ast(json_file)
#
# File ~/dev/astlib/src/astlib/ast.py:350, in json_to_ast(json_file)
#     348 with open(json_file) as f:
#     349     data = json.load(f)
# --> 350 return dict_to_ast(data, json_file.stem)
#
# File ~/dev/astlib/src/astlib/ast.py:342, in dict_to_ast(d, tuid)
#     339     raise Exception(f'Expected dict to be a translation unit, found "{d["kind"]}" instead')
#     341 ast = _new_astnode_class_from_dict(d, tuid)(d, tuid)
# --> 342 struct_lib = convert_structures_by_id(d['structures_by_id'], tuid)
#     343 StructTypeAndValueDeclLookup(struct_lib).extract(ast, save_result=True)
#     345 return (ast, struct_lib)
#
# KeyError: 'structures_by_id'
