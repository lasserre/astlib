# %%
# test this out with new Ghidra code...
import astlib
from pathlib import Path


# astlib.json_to_ast()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # test this out with new Ghidra code...
# ----> 2 import astlib
#       3 from pathlib import Path
#       6 # astlib.json_to_ast()
#
# File ~/dev/astlib/src/astlib/__init__.py:1
# ----> 1 from .ast import *
#       2 from .astvisitor import *
#       3 from .ghidra_scripts import *
#
# File ~/dev/astlib/src/astlib/ast.py:6
#       3 from pathlib import Path
#       4 from typing import Callable, Any, List, Dict
# ----> 6 from varlib import StructDatabase
#       7 from varlib.datatype import DataType, datatype_from_dict
#       8 from varlib.location import Location, LocationType
#
# File ~/dev/astlib/src/varlib/__init__.py:1
# ----> 1 from .structdatabase import StructDatabase
#       2 from .structlayout import StructDefinition, StructField, StructLayout
#       3 from .structtype import StructType, StructTypeBasic
#
# File ~/dev/astlib/src/varlib/structdatabase.py:6
#       3 from pathlib import Path
#       4 from typing import List, Dict, Iterable, Callable, Any
# ----> 6 from .structlayout import *
#       8 # NOTE: we avoid recursion by MAPPING a new structure type in the database
#       9 # even before we finish defining its fields
#      10
#    (...)
#      22 #      DO NOT BUILD A FULL DEFINITION FOR THIS
#      23 #       - e.g. int, float*, MyStruct, eType, int[5], FuncProto*
#      25 class StructDatabase:
#
# File ~/dev/astlib/src/varlib/structlayout.py:13
#       1 from typing import Dict, List
#       3 # throwing this together quickly, but the intent is to provide a helper class that helps
#       4 # import struct definitions from the AST, DWARF, etc. and manages some of the logic
#       5 # about unique struct definitions to prevent us from re-defining every struct type
#    (...)
#      10 # can wrap the internal definition of the structure layout (StructLayout) with properties
#      11 # to preserve the same API
# ---> 13 from .datatype import datatype_from_dict, DataType
#      15 class StructField:
#      16     '''
#      17     Do we want to call these fields or members? would be good to be consistent...
#      18     '''
#
# File ~/dev/astlib/src/varlib/datatype.py:407
#     394     @staticmethod
#     395     def from_dict(d:dict, sdb) -> 'FunctionType':
#     396         return FunctionType(datatype_from_dict(d['rdtype'], sdb),
#     397                 [datatype_from_dict(pdict, sdb) for pdict in d['inner']],
#     398                 d['name']
#     399             )
#     401 _dt_from_dict_methods = {
#     402     'ArrayType': ArrayType.from_dict,
#     403     'BuiltinType': BuiltinType.from_dict,
#     404     'EnumType': EnumType.from_dict,
#     405     'FunctionType': FunctionType.from_dict,
#     406     'PointerType': PointerType.from_dict,
# --> 407     'UnionType': UnionType.from_dict,
#     408 }
#     410 def datatype_from_dict(d:dict, sdb) -> 'DataType':
#     411     if d['kind'] not in _dt_from_dict_methods:
#
# NameError: name 'UnionType' is not defined

# %%
json_file = list((Path.home()/'test_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug').iterdir())[0]

# ast, _ = astlib.json_to_ast(json_file)
ast = astlib.read_json(json_file)
ast
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 json_file = list((Path.home()/'test_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug').iterdir())[0]
#       3 # ast, _ = astlib.json_to_ast(json_file)
# ----> 4 ast = astlib.read_json(json_file)
#       5 ast
#
# File ~/dev/astlib/src/astlib/ast.py:225, in read_json(json_file)
#     222     data = json.load(f)
#     223 # TODO: later, look for a .sdb file in the same folder, read it in and pass the
#     224 # struct database along
# --> 225 return astnode_from_dict(data)
#
# File ~/dev/astlib/src/astlib/ast.py:218, in astnode_from_dict(d, sdb)
#     216 if d['kind'] not in _module_classes:
#     217     raise NotImplementedError(f'No ASTNode class defined for node type "{d["kind"]}"')
# --> 218 return _module_classes[d['kind']].from_dict(d, sdb)
#
# File ~/dev/astlib/src/astlib/ast.py:199, in TranslationUnitDecl.from_dict(d, sdb)
#     196 @staticmethod
#     197 def from_dict(d:dict, sdb:StructDatabase) -> 'TranslationUnitDecl':
#     198     tudecl = TranslationUnitDecl()
# --> 199     tudecl._children_from_dict(d, sdb)
#     200     return tudecl
#
# File ~/dev/astlib/src/astlib/ast.py:95, in ASTNode._children_from_dict(self, d, sdb)
#      93 '''Helper function for ASTNodes to read in their child nodes'''
#      94 for child_dict in d['inner']:
# ---> 95     self.add_child(astnode_from_dict(child_dict, sdb))
#
# File ~/dev/astlib/src/astlib/ast.py:218, in astnode_from_dict(d, sdb)
#     216 if d['kind'] not in _module_classes:
#     217     raise NotImplementedError(f'No ASTNode class defined for node type "{d["kind"]}"')
# --> 218 return _module_classes[d['kind']].from_dict(d, sdb)
#
# File ~/dev/astlib/src/astlib/ast.py:185, in FunctionDecl.from_dict(d, sdb)
#     183 @staticmethod
#     184 def from_dict(d:dict, sdb:StructDatabase) -> 'FunctionDecl':
# --> 185     fd = FunctionDecl(d['id'], d['name'], int(d['address'], 16),
#     186         d['is_intrinsic'],
#     187         datatype_from_dict(d['return_dtype'], sdb),
#     188         params=[])
#     189     fd._children_from_dict(d, sdb)  # read params from inner
#     190     return fd
#
# TypeError: int() can't convert non-string with explicit base
