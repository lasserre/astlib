# %%
# test this out with new Ghidra code...
import astlib
from pathlib import Path


# astlib.json_to_ast()

# %%
debug_astdumps = Path.home()/'exp_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug'
[x for x in debug_astdumps.iterdir() if x.suffix != '.json']
# Out:
# [PosixPath('/home/cls0027/exp_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug/to_longest.log'),
#  PosixPath('/home/cls0027/exp_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug/to_target.log'),
#  PosixPath('/home/cls0027/exp_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug/from_target.log'),
#  PosixPath('/home/cls0027/exp_builds/binutils.exp/rundata/run1/0.gdb/ast_dumps/debug/0.gdb.debug_failed_decompilations.txt')]

# %%
for logfile in debug_astdumps.glob('*.log'):
    print(f'{logfile.name}:')
    with open(logfile, 'r') as f:
        for l in f.readlines():
            print(f'\t{l.strip()}')
    print()
# Out:
# to_longest.log:
# 	[todo] OP: opFloatNeg
#
# to_target.log:
# 	[todo] OP: opFloatNeg
# 	[todo] OP: opFloatNeg
#
# from_target.log:
# 	[todo] OP: opFloatNeg

# %%
failures = list(debug_astdumps.glob('*.txt'))[0]
lines = []
with open(failures, 'r') as f:
    lines = f.readlines()

print(f'Num failures = {len(lines)}')
for l in lines:
    print(l.strip())
# Out:
# Num failures = 99
# 517830
# 5201cf
# 57a341
# 5a8f5c
# 5b4667
# 5b49b7
# 63c207
# 63f89d
# 668624
# 66876d
# 66888e
# 66c049
# 674357
# 6823a6
# 6bb990
# 6c0bdc
# 701dfd
# 70318e
# 706d8f
# 731175
# 799fe8
# 7a9ebb
# 7bf255
# 7c1a14
# 7c75fb
# 7ded40
# 7e4248
# 7f08d6
# 7fca04
# 81bc20
# 81d8bf
# 830bbc
# 841af7
# 841fac
# 85bd34
# 87d1ef
# 880494
# 88d2cd
# 89708e
# 8e7c6f
# 90215c
# 935882
# 95d562
# 998d9e
# 9d08ae
# 9d97a3
# a48f7c
# a6232e
# a82f9b
# a8bb8d
# ad9292
# adb23e
# adb3b2
# adb544
# adc47c
# ae24c9
# ae3332
# ae340e
# ae34ea
# ae5c5b
# ae5d31
# ae5e07
# ae614d
# ae6224
# b0be9c
# b1703c
# b1abf1
# b21434
# b21563
# b3f1fc
# b4ad9b
# b4d020
# b4d13e
# b878cd
# b879df
# b8c60e
# b95afd
# c7685e
# c80595
# c89ccc
# c8a987
# c8b3f4
# c8b4c3
# c8bba2
# c8bc5b
# c8d535
# c8d6a4
# c8d7cd
# c8dac7
# c91236
# c91305
# c913ba
# c91478
# c9ced8
# cb9e98
# cb9f74
# cba05e
# cba13a
# cba26f

# %%
for json_file in debug_astdumps.glob('*.json'):
    print(f'Reading {json_file.name}')
    ast = astlib.read_json(json_file)

# %%
json_file = list(debug_astdumps.iterdir())[0]

# ast, _ = astlib.json_to_ast(json_file)
ast = astlib.read_json(json_file)
ast

# %%
expr = ast.inner[-1].inner[-1].inner[3].inner[0]

# %%
fd = expr.referencedDecl
# Out:
# new_allocator<std::__detail::_Hash_node<std::pair<const_std::__cxx11::basic_string<char,_std::char_traits<char>,_std::allocator<char>_>,_std::unique_ptr<target_desc,_target_desc_deleter>_>,_true>_>*
