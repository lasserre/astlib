# %%
from astlib import read_json
tudecl = read_json('OLD-AST-2-main.json')
tudecl
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from astlib import read_json
# ----> 2 tudecl = read_json('OLD-AST-2-main.json')
#       3 tudecl
#
# File ~/dev/astlib-pyhidra/src/astlib/ast.py:147, in read_json(json_file)
#     144     data = json.load(f)
#     145 # TODO: later, look for a .sdb file in the same folder, read it in and pass the
#     146 # struct database along
# --> 147 return astnode_from_dict(data)
#
# File ~/dev/astlib-pyhidra/src/astlib/ast.py:140, in astnode_from_dict(d, parent, sdb)
#     138 if d['kind'] not in _module_classes:
#     139     raise NotImplementedError(f'No ASTNode class defined for node type "{d["kind"]}"')
# --> 140 return _module_classes[d['kind']].from_dict(d, parent, sdb)
#
# File ~/dev/astlib-pyhidra/src/astlib/ast.py:106, in TranslationUnitDecl.from_dict(d, parent, sdb)
#     103 @staticmethod
# ...
